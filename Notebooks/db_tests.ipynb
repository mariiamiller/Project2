# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Dizengoff66@localhost:5432/earnings_latest')
connection = engine.connect()

# %%
earnings_data = pd.read_sql("SELECT * FROM earnings_latest", connection)
earnings_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aede6d923edb> in <module>
# ----> 1 earnings_data = pd.read_sql("SELECT * FROM earnings_latest", connection)
#       2 earnings_data.head()
#
# NameError: name 'connection' is not defined

# %%
import os

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session


from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import create_engine, inspect, func

# %%
Base = automap_base()

# %%
Base.prepare(db.engine, reflect=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-73c99375853c> in <module>
# ----> 1 Base.prepare(db.engine, reflect=True)
#
# NameError: name 'db' is not defined

# %%
engine = create_engine("sqlite:///earnings.sqlite", echo = False)

connection = engine.connect()

# %%
data = engine.execute("SELECT * FROM symbols")
for record in data:
    print(record)
# Out:
# (1, 'AAPL', 'Apple Inc.', 'http://www.nasdaq.com/symbol/aapl')
# (2, 'XOM', 'Exxon Mobil Corporation', 'http://www.nasdaq.com/symbol/xom')
# (3, 'MSFT', 'Microsoft Corporation', 'http://www.nasdaq.com/symbol/msft')
# (4, 'BAC^I', 'Bank of America Corporation', 'http://www.nasdaq.com/symbol/bac^i')
# (5, 'IBM', 'International Business Machines Corporation', 'http://www.nasdaq.com/symbol/ibm')
# (6, 'CVX', 'Chevron Corporation', 'http://www.nasdaq.com/symbol/cvx')
# (7, 'GE', 'General Electric Company', 'http://www.nasdaq.com/symbol/ge')
# (8, 'WMT', 'Wal-Mart Stores, Inc.', 'http://www.nasdaq.com/symbol/wmt')
# (9, 'T', 'AT&T Inc.', 'http://www.nasdaq.com/symbol/t')
# (10, 'JNJ', 'Johnson & Johnson', 'http://www.nasdaq.com/symbol/jnj')
# (11, 'PG', 'Procter & Gamble Company (The)', 'http://www.nasdaq.com/symbol/pg')
# (12, 'WFC', 'Wells Fargo & Company', 'http://www.nasdaq.com/symbol/wfc')
# (13, 'KO', 'Coca-Cola Company (The)', 'http://www.nasdaq.com/symbol/ko')
# ...

# %%
earnings_data = pd.read_sql("SELECT * FROM symbols", connection)

earnings_data.dropna(how = 'any')
earnings_data.head()
# Out:
#    id Symbol                                         Name  \
# 0   1   AAPL                                   Apple Inc.
# 1   2    XOM                      Exxon Mobil Corporation
# 2   3   MSFT                        Microsoft Corporation
# 3   4  BAC^I                  Bank of America Corporation
# 4   5    IBM  International Business Machines Corporation
#
#                          SummaryQuote
# 0   http://www.nasdaq.com/symbol/aapl
# 1    http://www.nasdaq.com/symbol/xom
# 2   http://www.nasdaq.com/symbol/msft
# 3  http://www.nasdaq.com/symbol/bac^i
# 4    http://www.nasdaq.com/symbol/ibm

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['Earnings', 'earnings_latest', 'sqlite_sequence', 'symbols']

# %%
columns = inspector.get_columns('symbols')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# Symbol TEXT
# Name TEXT
# SummaryQuote TEXT

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['Earnings', 'earnings_latest', 'symbols']

# %%
Earnings = Base.classes.Earnings

# %%
from sqlalchemy.orm import Session
session = Session(engine)

# %%
session.query(func.count(Earnings.date)).all()
# Out:
# [(141978)]

# %%
session.query(Earnings.date).order_by(Earnings.date).first()
# Out:
# ('2009-04-16')

# %%
session.query(Earnings.date).\
    filter(Earnings.date > '2018-03-01').\
    order_by(Earnings.date).all()
# Out:
# [('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-02'),
#  ('2018-03-04'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
#  ('2018-03-05'),
# ...

# %%
session.query(Earnings.eps).\
        filter(Earnings.eps).\
        order_by(Earnings.eps).all()
# Out:
# [(Decimal('-987.5400000000')),
#  (Decimal('-987.5400000000')),
#  (Decimal('-939.0000000000')),
#  (Decimal('-908.0000000000')),
#  (Decimal('-874.1300000000')),
#  (Decimal('-822.0000000000')),
#  (Decimal('-786.7100000000')),
#  (Decimal('-786.7100000000')),
#  (Decimal('-780.7800000000')),
#  (Decimal('-760.1800000000')),
#  (Decimal('-755.5600000000')),
#  (Decimal('-744.4400000000')),
#  (Decimal('-733.3300000000')),
#  (Decimal('-720.7200000000')),
#  (Decimal('-704.0000000000')),
#  (Decimal('-700.0000000000')),
#  (Decimal('-660.6600000000')),
#  (Decimal('-627.7800000000')),
#  (Decimal('-621.6200000000')),
#  (Decimal('-600.6000000000')),
#  (Decimal('-557.5000000000')),
#  (Decimal('-552.5500000000')),
#  (Decimal('-524.4800000000')),
#  (Decimal('-493.7700000000')),
#  (Decimal('-493.7700000000')),
#  (Decimal('-492.0000000000')),
#  (Decimal('-484.0000000000')),
#  (Decimal('-469.0000000000')),
#  (Decimal('-468.0000000000')),
#  (Decimal('-459.1500000000')),
# ...
