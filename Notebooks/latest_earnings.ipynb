# %%
import requests
import sqlite3
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://testuser:testpassword@localhost:5432/earning_latest', echo=False)

# %%
earnings = pd.read_csv('earnings_latest.csv')
earnings
# Out:
#        symbol        date      qtr  eps_est   eps release_time
# 0           A  2009-05-14  04/2009      NaN   NaN         post
# 1           A  2009-08-17  07/2009      NaN   NaN         post
# 2           A  2009-11-13  10/2009      NaN   NaN          pre
# 3           A  2010-02-12  01/2010      NaN   NaN          pre
# 4           A  2010-05-17  04/2010      NaN   NaN         post
# 5           A  2010-08-16  07/2010      NaN   NaN         post
# 6           A  2010-11-12  10/2010      NaN   NaN          pre
# 7           A  2011-02-14  01/2011      NaN   NaN         post
# 8           A  2011-05-13  04/2011      NaN   NaN          NaN
# 9           A  2011-08-15  07/2011      NaN   NaN         post
# 10          A  2011-11-15  10/2011      NaN   NaN         post
# 11          A  2012-02-15  01/2012      NaN   NaN         post
# 12          A  2012-05-14  04/2012      NaN   NaN         post
# 13          A  2012-08-15  07/2012      NaN   NaN         post
# ...

# %%
# Creating a DataFrame
df = pd.DataFrame(earnings)

# Adding a new column named surprise and surp_by_%
df.insert(5,"surprise", (""))
df.insert(6,"surp_by_%", (""))

# Creating formula for new colume values
df["surprise"] = df["eps"] - df["eps_est"]
df["surp_by_%"] = df["surprise"] / df["eps"] * 100  # surp_per = surp/eps_est*100%
df['surp_by_%'].round(3) 
df
# Out:
#        symbol        date      qtr  eps_est   eps  surprise  surp_by_%  \
# 0           A  2009-05-14  04/2009      NaN   NaN       NaN        NaN
# 1           A  2009-08-17  07/2009      NaN   NaN       NaN        NaN
# 2           A  2009-11-13  10/2009      NaN   NaN       NaN        NaN
# 3           A  2010-02-12  01/2010      NaN   NaN       NaN        NaN
# 4           A  2010-05-17  04/2010      NaN   NaN       NaN        NaN
# 5           A  2010-08-16  07/2010      NaN   NaN       NaN        NaN
# 6           A  2010-11-12  10/2010      NaN   NaN       NaN        NaN
# 7           A  2011-02-14  01/2011      NaN   NaN       NaN        NaN
# 8           A  2011-05-13  04/2011      NaN   NaN       NaN        NaN
# 9           A  2011-08-15  07/2011      NaN   NaN       NaN        NaN
# 10          A  2011-11-15  10/2011      NaN   NaN       NaN        NaN
# 11          A  2012-02-15  01/2012      NaN   NaN       NaN        NaN
# ...

# %%
df["surp_by_%"] = pd.to_numeric(df["surp_by_%"], errors='coerce')
df
# Out:
#        symbol        date      qtr  eps_est   eps  surprise  surp_by_%  \
# 0           A  2009-05-14  04/2009      NaN   NaN       NaN        NaN
# 1           A  2009-08-17  07/2009      NaN   NaN       NaN        NaN
# 2           A  2009-11-13  10/2009      NaN   NaN       NaN        NaN
# 3           A  2010-02-12  01/2010      NaN   NaN       NaN        NaN
# 4           A  2010-05-17  04/2010      NaN   NaN       NaN        NaN
# 5           A  2010-08-16  07/2010      NaN   NaN       NaN        NaN
# 6           A  2010-11-12  10/2010      NaN   NaN       NaN        NaN
# 7           A  2011-02-14  01/2011      NaN   NaN       NaN        NaN
# 8           A  2011-05-13  04/2011      NaN   NaN       NaN        NaN
# 9           A  2011-08-15  07/2011      NaN   NaN       NaN        NaN
# 10          A  2011-11-15  10/2011      NaN   NaN       NaN        NaN
# 11          A  2012-02-15  01/2012      NaN   NaN       NaN        NaN
# ...

# %%
df.round({"surp_by_%":3})
# Out:
#        symbol        date      qtr  eps_est   eps  surprise  surp_by_%  \
# 0           A  2009-05-14  04/2009      NaN   NaN       NaN        NaN
# 1           A  2009-08-17  07/2009      NaN   NaN       NaN        NaN
# 2           A  2009-11-13  10/2009      NaN   NaN       NaN        NaN
# 3           A  2010-02-12  01/2010      NaN   NaN       NaN        NaN
# 4           A  2010-05-17  04/2010      NaN   NaN       NaN        NaN
# 5           A  2010-08-16  07/2010      NaN   NaN       NaN        NaN
# 6           A  2010-11-12  10/2010      NaN   NaN       NaN        NaN
# 7           A  2011-02-14  01/2011      NaN   NaN       NaN        NaN
# 8           A  2011-05-13  04/2011      NaN   NaN       NaN        NaN
# 9           A  2011-08-15  07/2011      NaN   NaN       NaN        NaN
# 10          A  2011-11-15  10/2011      NaN   NaN       NaN        NaN
# 11          A  2012-02-15  01/2012      NaN   NaN       NaN        NaN
# ...

# %%
pd.to_datetime(df['date'])
# Out:
# 0        2009-05-14
# 1        2009-08-17
# 2        2009-11-13
# 3        2010-02-12
# 4        2010-05-17
# 5        2010-08-16
# 6        2010-11-12
# 7        2011-02-14
# 8        2011-05-13
# 9        2011-08-15
# 10       2011-11-15
# 11       2012-02-15
# 12       2012-05-14
# 13       2012-08-15
# 14       2012-11-19
# 15       2013-02-14
# 16       2013-05-14
# 17       2013-08-14
# 18       2013-11-14
# 19       2014-02-13
# 20       2014-05-14
# 21       2014-08-14
# 22       2014-11-17
# 23       2015-02-17
# 24       2015-05-18
# 25       2015-08-17
# 26       2015-11-16
# 27       2016-02-16
# 28       2016-05-16
# 29       2016-08-17
#             ...
# 141948   2017-05-15
# 141949   2017-08-08
# 141950   2017-11-08
# 141951   2018-03-14
# 141952   2018-05-01
# 141953   2018-08-01
# 141954   2018-11-06
# 141955   2019-03-06
# 141956   2019-05-02
# 141957   2019-08-02
# 141958   2015-08-27
# 141959   2015-11-11
# 141960   2016-03-14
# 141961   2016-05-12
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
df['qtr'] = df['date'].dt.year.astype(str) + 'Q' + df['date'].dt.quarter.astype(str)

# %%
df
# Out:
#        symbol       date     qtr  eps_est   eps  surprise  surp_by_%  \
# 0           A 2009-05-14  2009Q2      NaN   NaN       NaN        NaN
# 1           A 2009-08-17  2009Q3      NaN   NaN       NaN        NaN
# 2           A 2009-11-13  2009Q4      NaN   NaN       NaN        NaN
# 3           A 2010-02-12  2010Q1      NaN   NaN       NaN        NaN
# 4           A 2010-05-17  2010Q2      NaN   NaN       NaN        NaN
# 5           A 2010-08-16  2010Q3      NaN   NaN       NaN        NaN
# 6           A 2010-11-12  2010Q4      NaN   NaN       NaN        NaN
# 7           A 2011-02-14  2011Q1      NaN   NaN       NaN        NaN
# 8           A 2011-05-13  2011Q2      NaN   NaN       NaN        NaN
# 9           A 2011-08-15  2011Q3      NaN   NaN       NaN        NaN
# 10          A 2011-11-15  2011Q4      NaN   NaN       NaN        NaN
# 11          A 2012-02-15  2012Q1      NaN   NaN       NaN        NaN
# 12          A 2012-05-14  2012Q2      NaN   NaN       NaN        NaN
# ...

# %%
dfcsv = df.to_csv(r'C:\Users\chaim\Downloads\us-historical-stock-prices-with-earnings-data\stocks_latest\df_csv.csv')
dfcsv

# %%
cnx = sqlite3.connect('earnings_L_db.sqlite')
df.to_sql('earnings_latest', cnx)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b3985b7612f4> in <module>
#       1 cnx = sqlite3.connect('earnings_L_db.sqlite')
# ----> 2 df.to_sql('earnings_latest', cnx)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
# ...

# %%
df.to_sql('ern', con=engine)
engine.execute("SELECT * FROM ern").fetchall()
[(0, 'symbol'), (1, 'date'), (2, 'qtr'), (3, 'eps_est'),(4,'release_time'),(5,'surprise'),(6,'surp_by_%')]
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     772         else:
# --> 773             cursor.executemany(statement, parameters)
#     774
#
# ProgrammingError: incomplete placeholder: '%(' without ')'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-d1b2bd4f5dc4> in <module>
# ----> 1 df.to_sql('ern', con=engine)
# ...

# %%
#df_no_duplicates = pd.DataFrame()
#df_no_duplicates['symbol'] = df['symbol'].drop_duplicates()
#df_no_duplicates
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'symbol'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-0014092100d1> in <module>
#       1 df_no_duplicates = pd.DataFrame()
# ...

# %%
# Creating a list of all symbols at first
sym = df['symbol'].value_counts().index.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'symbol'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-4bb353e4693b> in <module>
#       1 # Creating a list of all symbols at first
# ...

# %%
# Python3 program to convert list into a list of lists of symbols
  
def extractList(lst): 
    res = [] 
    for el in lst: 
        sub = el.split(', ') 
        res.append(sub) 
      
    return(res) 
                  
# Driver code 
symb = print(extractList(sym))
# Out:
# [['MGI'], ['SINA'], ['SUMR'], ['MHLD'], ['IAG'], ['PRA'], ['IPI'], ['WEX'], ['FTK'], ['CYCC'], ['TEVA'], ['SQM'], ['ATSG'], ['LINC'], ['ESV'], ['SJI'], ['MCRI'], ['CMCO'], ['CSV'], ['RAIL'], ['CWCO'], ['NCI'], ['POL'], ['IMMU'], ['DDS'], ['EXAS'], ['EVC'], ['PSB'], ['GTE'], ['RDN'], ['SBBX'], ['FOE'], ['SWX'], ['NVDA'], ['MCHP'], ['ATRO'], ['GSS'], ['CCO'], ['BMA'], ['WAB'], ['MIDD'], ['ASTE'], ['LL'], ['LGCY'], ['MCY'], ['TOL'], ['HCCI'], ['PSA'], ['MNTX'], ['CLMT'], ['PBI'], ['HOFT'], ['MAIN'], ['CEVA'], ['EXPD'], ['CKH'], ['ED'], ['SLF'], ['MSEX'], ['ARCC'], ['BR'], ['AEL'], ['LNC'], ['FMX'], ['SYMC'], ['AFG'], ['TDC'], ['MNRO'], ['TGT'], ['ATRC'], ['CXO'], ['EIX'], ['CROX'], ['SM'], ['DRRX'], ['CUTR'], ['ENSG'], ['HOLX'], ['MNKD'], ['HTGC'], ['DISCA'], ['CECE'], ['MSTR'], ['MYGN'], ['ADM'], ['AGEN'], ['SBGI'], ['LGND'], ['SSP'], ['HCKT'], ['GHDX'], ['XPO'], ['AWK'], ['NBIX'], ['TREE'], ['NOA'], ['CBPO'], ['VGR'], ['GHM'], ['ALL'], ['IT'], ['TEN'], ['AVD'], ['LLNW'], ['PNW'], ['CT
# ...

# %%
df.sort_values([0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-dd6c6213917d> in <module>
# ----> 1 df.sort_values([0])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 0

# %%
for ind in df.index:
    if symb['symbol'] == df[['symbol']]:
        symb[s].append(ind['eps'],ind['surprise'])
    print(symb[[element]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-59bb626da26c> in <module>
#       1 for ind in df.index:
# ----> 2     if symb['symbol'] == df[['symbol']]:
#       3         symb[s].append(ind['eps'],ind['surprise'])
#       4     print(symb[[element]])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
symbols_dict = dict()
for symbol in sym:
    symbols_dict[symbol] = df.loc[symbol,:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'MGI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c017afe9a924> in <module>
#       1 symbols_dict = dict()
#       2 for symbol in sym:
# ----> 3     symbols_dict[symbol] = df.loc[symbol,:]
#
# ...

# %%
df.set_index('symbol',inplace=True)

# %%
df.loc['LPSN',:]
# Out:
#               date      qtr  eps_est   eps  surprise   surp_by_% release_time
# symbol
# LPSN    2009-05-06  03/2009      NaN   NaN       NaN         NaN         post
# LPSN    2009-08-04  06/2009      NaN   NaN       NaN         NaN         post
# LPSN    2009-11-05  09/2009      NaN   NaN       NaN         NaN         post
# LPSN    2010-02-10  12/2009      NaN   NaN       NaN         NaN         post
# LPSN    2010-05-05  03/2010      NaN   NaN       NaN         NaN         post
# LPSN    2010-08-04  06/2010      NaN   NaN       NaN         NaN         post
# LPSN    2010-11-04  09/2010      NaN   NaN       NaN         NaN         post
# LPSN    2011-02-10  12/2010      NaN   NaN       NaN         NaN          NaN
# LPSN    2011-05-02  03/2011      NaN   NaN       NaN         NaN         post
# LPSN    2011-08-03  06/2011      NaN   NaN       NaN         NaN         post
# LPSN    2011-11-03  09/2011      NaN   NaN       NaN         NaN         post
# ...

# %%
df=pd.DataFrame(columns=['date','open','high','low','close','volume'])

# %%
for d,p in data.items():
    date=datetime.datetime.strptime(d,'%Y-%m-%d %H:%M:%S')
    data_row=[date,float(p['1. open']),float(p['2. high']),float(p['3. low']),float(p['4. close']),int(p['5. volume'])]
    df.loc[-1,:]=data_row
    df.index=df.index+1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-cdd10f899e3c> in <module>
#       1 for d,p in data.items():
# ----> 2     date=datetime.datetime.strptime(d,'%Y-%m-%d')
#       3     data_row=[date,float(p['1. open']),float(p['2. high']),float(p['3. low']),float(p['4. close']),int(p['5. volume'])]
#       4     df.loc[-1,:]=data_row
#       5     df.index=df.index+1
#
# ~\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     357     if not found:
# ...

# %%
data=df.sort_values('date')

# %%
data['close']=data['close'].astype(float)
data['5min']=np.round(data['close'].rolling(window=5).mean(),2)
data[['5min','close']].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0c3a8efc2220> in <module>
#       1 data['close']=data['close'].astype(float)
#       2 data['5min']=np.round(data['close'].rolling(window=5).mean(),2)
# ----> 3 data[['5min','close']].plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ...

# %%
data['close']=data['close'].astype(float)
data['5min']=np.round(data['close'].rolling(window=5).mean(),2)
data[['5min','close']].plot()
plt.show()
