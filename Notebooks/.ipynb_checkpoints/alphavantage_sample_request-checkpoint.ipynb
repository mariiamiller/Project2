# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import json

# Import API key
api_key =  "V9FZCMP0HRSJA6B"

# %%
base_url = "https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AMZN&interval=5min&apikey="+api_key

symbol = "BA"
price_time = "TIME_SERIES_INTRADAY"
interval = "5min"
url =  f"{base_url}function={price_time}&symbol={symbol}&interval={interval}&apikey={api_key}"
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Intraday (5min) open, high, low, close prices and volume",
#         "2. Symbol": "BA",
#         "3. Last Refreshed": "2019-11-04 16:00:00",
#         "4. Interval": "5min",
#         "5. Output Size": "Compact",
#         "6. Time Zone": "US/Eastern"
#     },
#     "Time Series (5min)": {
#         "2019-11-01 14:15:00": {
#             "1. open": "343.5600",
#             "2. high": "343.5600",
#             "3. low": "343.2808",
#             "4. close": "343.3182",
#             "5. volume": "20931"
#         },
#         "2019-11-01 14:20:00": {
#             "1. open": "343.3000",
#             "2. high": "343.3000",
#             "3. low": "342.1200",
#             "4. close": "342.1200",
#             "5. volume": "94243"
#         },
#         "2019-11-01 14:25:00": {
#             "1. open": "342.1739",
#             "2. high": "342.9600",
#             "3. low": "341.8990",
#             "4. close": "342.8644",
# ...

# %%
len(response.get("Time Series (5min)"))
# Out:
# 100

# %%
last_date = list(response["Time Series (5min)"].keys())[0]

# %%
#CURRENT PRICE BOX
last_date
# Out:
# '2019-11-04 16:00:00'

# %%
last_value = list(response["Time Series (5min)"].values())[0]

# %%
last_value
# Out:
# {'1. open': '350.9000',
#  '2. high': '351.1000',
#  '3. low': '350.6500',
#  '4. close': '351.0700',
#  '5. volume': '174981'}

# %%
base_url = "https://www.alphavantage.co/query?"

symbol = "BA"
price_time = "TIME_SERIES_DAILY_ADJUSTED"
interval = "5min"
url =  f"{base_url}function={price_time}&symbol={symbol}&outputsize=full&apikey={api_key}"
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Daily Time Series with Splits and Dividend Events",
#         "2. Symbol": "BA",
#         "3. Last Refreshed": "2019-11-08",
#         "4. Output Size": "Full size",
#         "5. Time Zone": "US/Eastern"
#     },
#     "Time Series (Daily)": {
#         "1999-11-09": {
#             "1. open": "44.1880",
#             "2. high": "44.3130",
#             "3. low": "41.1250",
#             "4. close": "41.4380",
#             "5. adjusted close": "26.7000",
#             "6. volume": "6795300",
#             "7. dividend amount": "0.1400",
#             "8. split coefficient": "1.0000"
#         },
#         "1999-11-10": {
#             "1. open": "41.4380",
#             "2. high": "42.3130",
#             "3. low": "40.9380",
#             "4. close": "41.7500",
#             "5. adjusted close": "26.9014",
#             "6. volume": "5828600",
#             "7. dividend amount": "0.0000",
# ...

# %%
df= pd.DataFrame(response.get("Time Series (Daily)"))
df.head()
# Out:
#                   2019-11-04 2019-11-01 2019-10-31 2019-10-30 2019-10-29  \
# 1. open             346.4600   340.5900   344.7000   346.6300   340.1900
# 2. high             351.4500   345.1900   346.0600   350.0000   349.7200
# 3. low              346.0500   339.5000   339.4500   343.2700   339.2200
# 4. close            351.0900   345.1900   339.9100   346.0600   348.9300
# 5. adjusted close   351.0900   345.1900   339.9100   346.0600   348.9300
#
#                   2019-10-28 2019-10-25 2019-10-24 2019-10-23 2019-10-22  ...  \
# 1. open             341.5000   342.9200   341.7000   345.0000   336.0700  ...
# 2. high             344.9800   343.3700   345.7400   350.8000   341.4800  ...
# 3. low              339.4900   338.9000   337.7700   336.5000   334.4600  ...
# 4. close            340.8800   339.8300   344.5500   340.5000   337.0000  ...
# 5. adjusted close   340.8800   339.8300   344.5500   340.5000   337.0000  ...
#
# ...

# %%
sample_daily = df.T.reset_index()
sample_daily = sample_daily.sort_values(by='index', ascending=True )
sample_daily.head()
# Out:
#            index  1. open  2. high   3. low 4. close 5. adjusted close  \
# 5033  1999-11-02  43.6880  43.6880  42.3750  43.3750           28.0225
# 5032  1999-11-03  43.3750  44.1250  42.2500  43.2500           27.9417
# 5031  1999-11-04  43.2500  43.9380  43.0630  43.3750           28.0225
# 5030  1999-11-05  44.0630  44.9387  44.0630  44.3130           28.6282
# 5029  1999-11-08  44.3130  44.8750  43.7500  44.1880           28.5474
#
#      6. volume 7. dividend amount 8. split coefficient
# 5033   6561200             0.0000               1.0000
# 5032   5700800             0.0000               1.0000
# 5031   2729000             0.0000               1.0000
# 5030   3640900             0.0000               1.0000
# 5029   2888200             0.0000               1.0000

# %%
#plt.plot(sample_daily['index'], sample_daily['5. adjusted close'])
#plot.show()

# %%
sample100 = sample_daily.tail(100)
sample100
# Out:
#          index   1. open   2. high    3. low  4. close 5. adjusted close  \
# 99  2019-06-14  348.0000  349.1700  345.8900  347.1600          345.0071
# 98  2019-06-17  348.6200  356.0500  347.0500  354.9000          352.6992
# 97  2019-06-18  357.6158  374.6500  357.6000  373.9600          371.6409
# 96  2019-06-19  375.4000  379.3100  368.3500  368.5600          366.2744
# 95  2019-06-20  373.0000  375.7900  368.9453  374.8800          372.5552
# 94  2019-06-21  374.3900  376.1100  371.7200  371.8400          369.5341
# 93  2019-06-24  372.9500  375.4900  372.1000  373.9900          371.6707
# 92  2019-06-25  374.7500  375.2500  368.0300  369.3200          367.0297
# 91  2019-06-26  371.0200  378.9800  370.0000  374.9400          372.6149
# 90  2019-06-27  367.5400  369.9300  362.3500  364.0200          361.7626
# 89  2019-06-28  363.9200  366.2300  361.5700  364.0100          361.7527
# 88  2019-07-01  364.8800  365.2300  353.3200  356.4600          354.2495
# ...

# %%
plt.scatter(sample100['index'], sample100['5. adjusted close'])
plt.show()

# %%
sample100['5. adjusted close'].dtype
# Out:
# dtype('O')

# %%
sample100['5. adjusted close'] = sample100['5. adjusted close'].astype(float)
# Out:
# C:\Users\marii\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(sample100['index'], sample100['5. adjusted close'])
plt.show()
