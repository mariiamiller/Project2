# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
import json

# %%
base_url="https://api.earningscalendar.net/?date=2019101"

response = requests.get(base_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "ticker": "RAD",
#         "when": "bmo"
#     },
#     {
#         "ticker": "KSHB",
#         "when": "--"
#     },
#     {
#         "ticker": "FAST",
#         "when": "bmo"
#     },
#     {
#         "ticker": "CBSH",
#         "when": "bmo"
#     },
#     {
#         "ticker": "APOG",
#         "when": "bmo"
#     }
# ]

# %%
len(response)
# Out:
# 289

# %%
earnings = []
for j in range (1,5):
    base_url="https://api.earningscalendar.net/?date=2019100"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191001
# ['SFIX', '2019-10-01', 'amc']
# SFIX
# ['MKC', '2019-10-01', 'bmo']
# MKC
# ['UNFI', '2019-10-01', 'amc']
# UNFI
# ['SSNLF', '2019-10-01', '--']
# SSNLF
# ['DNZOY', '2019-10-01', '--']
# DNZOY
# ['LGRVF', '2019-10-01', '--']
# LGRVF
# ['ASEKY', '2019-10-01', '--']
# ASEKY
# ['NG', '2019-10-01', 'amc']
# NG
# ['LNDC', '2019-10-01', 'amc']
# LNDC
# ['CTST', '2019-10-01', '--']
# CTST
# ['AMRQQ', '2019-10-01', '--']
# AMRQQ
# https://api.earningscalendar.net/?date=20191002
# ['LEN', '2019-10-02', 'bmo']
# LEN
# ['BBBY', '2019-10-02', 'amc']
# BBBY
# ['LW', '2019-10-02', 'bmo']
# LW
# ['PAYX', '2019-10-02', 'bmo']
# PAYX
# ['RECN', '2019-10-02', '--']
# RECN
# ['AYI', '2019-10-02', 'bmo']
# AYI
# ['RPM', '2019-10-02', 'bmo']
# RPM
# https://api.earningscalendar.net/?date=20191003
# ['STZ', '2019-10-03', 'bmo']
# STZ
# ['COST', '2019-10-03', 'amc']
# COST
# ['SGH', '2019-10-03', 'amc']
# SGH
# ['PEP', '2019-10-03', 'bmo']
# PEP
# ...

# %%
for j in range (5,10):
    base_url="https://api.earningscalendar.net/?date=2019100"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191005
# https://api.earningscalendar.net/?date=20191006
# https://api.earningscalendar.net/?date=20191007
# https://api.earningscalendar.net/?date=20191008
# ['DPZ', '2019-10-08', 'bmo']
# DPZ
# ['HELE', '2019-10-08', 'bmo']
# HELE
# ['LEVI', '2019-10-08', 'amc']
# LEVI
# https://api.earningscalendar.net/?date=20191009
# ['SAR', '2019-10-09', 'amc']
# SAR
# ['TMQ', '2019-10-09', '--']
# TMQ
# ['EXFO', '2019-10-09', 'amc']
# EXFO
# [['SFIX', '2019-10-01', 'amc'],
#  ['MKC', '2019-10-01', 'bmo'],
#  ['UNFI', '2019-10-01', 'amc'],
#  ['SSNLF', '2019-10-01', '--'],
#  ['DNZOY', '2019-10-01', '--'],
#  ['LGRVF', '2019-10-01', '--'],
#  ['ASEKY', '2019-10-01', '--'],
#  ['NG', '2019-10-01', 'amc'],
#  ['LNDC', '2019-10-01', 'amc'],
#  ['CTST', '2019-10-01', '--'],
#  ['AMRQQ', '2019-10-01', '--'],
#  ['LEN', '2019-10-02', 'bmo'],
#  ['BBBY', '2019-10-02', 'amc'],
#  ['LW', '2019-10-02', 'bmo'],
#  ['PAYX', '2019-10-02', 'bmo'],
# ...

# %%
for j in range (10,15):
    base_url="https://api.earningscalendar.net/?date=201910"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191010
# ['DAL', '2019-10-10', 'bmo']
# DAL
# https://api.earningscalendar.net/?date=20191011
# ['FAST', '2019-10-11', 'bmo']
# FAST
# ['INFY', '2019-10-11', 'bmo']
# INFY
# ['SMMT', '2019-10-11', '--']
# SMMT
# https://api.earningscalendar.net/?date=20191012
# https://api.earningscalendar.net/?date=20191013
# https://api.earningscalendar.net/?date=20191014
# [['SFIX', '2019-10-01', 'amc'],
#  ['MKC', '2019-10-01', 'bmo'],
#  ['UNFI', '2019-10-01', 'amc'],
#  ['SSNLF', '2019-10-01', '--'],
#  ['DNZOY', '2019-10-01', '--'],
#  ['LGRVF', '2019-10-01', '--'],
#  ['ASEKY', '2019-10-01', '--'],
#  ['NG', '2019-10-01', 'amc'],
#  ['LNDC', '2019-10-01', 'amc'],
#  ['CTST', '2019-10-01', '--'],
#  ['AMRQQ', '2019-10-01', '--'],
#  ['LEN', '2019-10-02', 'bmo'],
#  ['BBBY', '2019-10-02', 'amc'],
#  ['LW', '2019-10-02', 'bmo'],
#  ['PAYX', '2019-10-02', 'bmo'],
#  ['RECN', '2019-10-02', '--'],
#  ['AYI', '2019-10-02', 'bmo'],
# ...

# %%
for j in range (15,20):
    base_url="https://api.earningscalendar.net/?date=201910"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191015
# ['JNJ', '2019-10-15', 'bmo']
# JNJ
# ['JPM', '2019-10-15', 'bmo']
# JPM
# ['UNH', '2019-10-15', 'bmo']
# UNH
# ['C', '2019-10-15', 'bmo']
# C
# ['GS', '2019-10-15', 'bmo']
# GS
# ['WFC', '2019-10-15', 'bmo']
# WFC
# ['UAL', '2019-10-15', 'amc']
# UAL
# ['APHA', '2019-10-15', 'bmo']
# APHA
# ['BLK', '2019-10-15', 'bmo']
# BLK
# ['SCHW', '2019-10-15', 'bmo']
# SCHW
# ['FGP', '2019-10-15', '--']
# FGP
# ['JBHT', '2019-10-15', 'amc']
# JBHT
# ['PLD', '2019-10-15', 'bmo']
# PLD
# ['OMC', '2019-10-15', 'bmo']
# OMC
# ['AMX', '2019-10-15', '--']
# AMX
# ['FRC', '2019-10-15', 'bmo']
# FRC
# ['WIT', '2019-10-15', 'bmo']
# WIT
# ['TW', '2019-10-15', 'bmo']
# TW
# ['PNFP', '2019-10-15', 'amc']
# PNFP
# ['HWC', '2019-10-15', 'amc']
# HWC
# ['WAFD', '2019-10-15', '--']
# WAFD
# ['SNBR', '2019-10-15', 'amc']
# SNBR
# ['NCBS', '2019-10-15', '--']
# NCBS
# ['MBWM', '2019-10-15', 'bmo']
# MBWM
# ['PTSI', '2019-10-15', '--']
# PTSI
# ...

# %%
for j in range (20,25):
    base_url="https://api.earningscalendar.net/?date=201910"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191020
# https://api.earningscalendar.net/?date=20191021
# ['HAL', '2019-10-21', 'bmo']
# HAL
# ['LOGI', '2019-10-21', 'amc']
# LOGI
# ['AMTD', '2019-10-21', 'amc']
# AMTD
# ['CE', '2019-10-21', 'amc']
# CE
# ['CDNS', '2019-10-21', 'amc']
# CDNS
# ['ZION', '2019-10-21', 'amc']
# ZION
# ['SAP', '2019-10-21', 'bmo']
# SAP
# ['HLX', '2019-10-21', 'amc']
# HLX
# ['HXL', '2019-10-21', 'amc']
# HXL
# ['ATLKY', '2019-10-21', '--']
# ATLKY
# ['ELS', '2019-10-21', 'amc']
# ELS
# ['LII', '2019-10-21', 'bmo']
# LII
# ['ACC', '2019-10-21', 'amc']
# ACC
# ['SARTF', '2019-10-21', '--']
# SARTF
# ['CBU', '2019-10-21', 'bmo']
# CBU
# ['BXS', '2019-10-21', 'amc']
# BXS
# ['ADC', '2019-10-21', 'amc']
# ADC
# ['ONB', '2019-10-21', 'bmo']
# ONB
# ['IBTX', '2019-10-21', 'amc']
# IBTX
# ['WSFS', '2019-10-21', 'amc']
# WSFS
# ['RNST', '2019-10-21', 'amc']
# RNST
# ['SFBS', '2019-10-21', 'amc']
# SFBS
# ['HOPE', '2019-10-21', 'amc']
# HOPE
# ...

# %%
for j in range (25,32):
    base_url="https://api.earningscalendar.net/?date=201910"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-10-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191025
# ['VZ', '2019-10-25', 'bmo']
# VZ
# ['NRZ', '2019-10-25', 'bmo']
# NRZ
# ['PSX', '2019-10-25', 'bmo']
# PSX
# ['VFC', '2019-10-25', 'bmo']
# VFC
# ['HUN', '2019-10-25', 'bmo']
# HUN
# ['VTR', '2019-10-25', 'bmo']
# VTR
# ['BUD', '2019-10-25', 'bmo']
# BUD
# ['BCS', '2019-10-25', 'bmo']
# BCS
# ['WY', '2019-10-25', 'bmo']
# WY
# ['ITW', '2019-10-25', 'bmo']
# ITW
# ['PSXP', '2019-10-25', 'bmo']
# PSXP
# ['GBX', '2019-10-25', 'bmo']
# GBX
# ['GT', '2019-10-25', 'bmo']
# GT
# ['SJR', '2019-10-25', 'bmo']
# SJR
# ['CHTR', '2019-10-25', 'bmo']
# CHTR
# ['UFS', '2019-10-25', 'bmo']
# UFS
# ['YNDX', '2019-10-25', 'bmo']
# YNDX
# ['BEN', '2019-10-25', 'bmo']
# BEN
# ['LEA', '2019-10-25', 'bmo']
# LEA
# ['SCCO', '2019-10-25', '--']
# SCCO
# ['AON', '2019-10-25', 'bmo']
# AON
# ['ALV', '2019-10-25', 'bmo']
# ALV
# ['KEX', '2019-10-25', 'bmo']
# KEX
# ['B', '2019-10-25', 'bmo']
# B
# ['ROCK', '2019-10-25', 'bmo']
# ROCK
# ...

# %%
len(earnings)
# Out:
# 1796

# %%
earnings[1795]
# Out:
# ['BIOVF', '2019-10-31', '--']

# %%
for j in range (1,5):
    base_url="https://api.earningscalendar.net/?date=2019110"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings
# Out:
# https://api.earningscalendar.net/?date=20191101
# ['BABA', '2019-11-01', 'bmo']
# BABA
# ['ABBV', '2019-11-01', 'bmo']
# ABBV
# ['XOM', '2019-11-01', 'bmo']
# XOM
# ['CVX', '2019-11-01', 'bmo']
# CVX
# ['D', '2019-11-01', 'bmo']
# D
# ['ABR', '2019-11-01', 'bmo']
# ABR
# ['STX', '2019-11-01', 'bmo']
# STX
# ['NWL', '2019-11-01', 'bmo']
# NWL
# ['MSEX', '2019-11-01', '--']
# MSEX
# ['TRP', '2019-11-01', 'bmo']
# TRP
# ['CL', '2019-11-01', 'bmo']
# CL
# ['UUUU', '2019-11-01', '--']
# UUUU
# ['WPC', '2019-11-01', 'bmo']
# WPC
# ['HMSY', '2019-11-01', 'bmo']
# HMSY
# ['LNG', '2019-11-01', 'bmo']
# LNG
# ['LYB', '2019-11-01', 'bmo']
# LYB
# ['AIG', '2019-11-01', 'bmo']
# AIG
# ['CCJ', '2019-11-01', 'bmo']
# CCJ
# ['NVO', '2019-11-01', 'bmo']
# NVO
# ['CQP', '2019-11-01', '--']
# CQP
# ['HE', '2019-11-01', 'bmo']
# HE
# ['BAH', '2019-11-01', 'bmo']
# BAH
# ['AXL', '2019-11-01', 'bmo']
# AXL
# ['POR', '2019-11-01', 'bmo']
# POR
# ['CBOE', '2019-11-01', 'bmo']
# CBOE
# ...

# %%
for j in range (5,10):
    base_url="https://api.earningscalendar.net/?date=2019110"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191105
# ['BEAT', '2019-11-05', 'amc']
# BEAT
# ['CHK', '2019-11-05', 'bmo']
# CHK
# ['AMRN', '2019-11-05', 'bmo']
# AMRN
# ['OHI', '2019-11-05', 'amc']
# OHI
# ['GWPH', '2019-11-05', 'amc']
# GWPH
# ['FTR', '2019-11-05', 'amc']
# FTR
# ['AEZS', '2019-11-05', '--']
# AEZS
# ['PPL', '2019-11-05', 'bmo']
# PPL
# ['HCHC', '2019-11-05', 'amc']
# HCHC
# ['AGN', '2019-11-05', 'bmo']
# AGN
# ['INGN', '2019-11-05', 'amc']
# INGN
# ['GHDX', '2019-11-05', '--']
# GHDX
# ['NEWR', '2019-11-05', 'amc']
# NEWR
# ['MTCH', '2019-11-05', 'amc']
# MTCH
# ['ATH', '2019-11-05', 'bmo']
# ATH
# ['UNT', '2019-11-05', '--']
# UNT
# ['CCR', '2019-11-05', 'bmo']
# CCR
# ['GLDD', '2019-11-05', 'bmo']
# GLDD
# ['GTE', '2019-11-05', 'amc']
# GTE
# ['OPK', '2019-11-05', 'amc']
# OPK
# ['VCEL', '2019-11-05', 'bmo']
# VCEL
# ['REGN', '2019-11-05', 'bmo']
# REGN
# ['ALRM', '2019-11-05', 'amc']
# ALRM
# ['TWO', '2019-11-05', 'amc']
# TWO
# ['EMR', '2019-11-05', 'bmo']
# EMR
# ...

# %%
for j in range (10,15):
    base_url="https://api.earningscalendar.net/?date=201911"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191110
# https://api.earningscalendar.net/?date=20191111
# ['ACB', '2019-11-11', '--']
# ACB
# ['KEM', '2019-11-11', 'bmo']
# KEM
# ['DXC', '2019-11-11', 'amc']
# DXC
# ['CTEK', '2019-11-11', 'bmo']
# CTEK
# ['IFNNY', '2019-11-11', '--']
# IFNNY
# ['FNV', '2019-11-11', 'amc']
# FNV
# ['UGI', '2019-11-11', 'amc']
# UGI
# ['FOE', '2019-11-11', 'amc']
# FOE
# ['ASUR', '2019-11-11', 'amc']
# ASUR
# ['APYX', '2019-11-11', 'amc']
# APYX
# ['CGEN', '2019-11-11', 'bmo']
# CGEN
# ['TME', '2019-11-11', 'amc']
# TME
# ['FGEN', '2019-11-11', 'amc']
# FGEN
# ['NEPT', '2019-11-11', 'bmo']
# NEPT
# ['HBM', '2019-11-11', 'amc']
# HBM
# ['FOLD', '2019-11-11', 'bmo']
# FOLD
# ['LBRDK', '2019-11-11', 'amc']
# LBRDK
# ['FWONK', '2019-11-11', 'bmo']
# FWONK
# ['LSXMK', '2019-11-11', 'bmo']
# LSXMK
# ['GLIBA', '2019-11-11', 'amc']
# GLIBA
# ['QRTEA', '2019-11-11', 'bmo']
# QRTEA
# ['ICUI', '2019-11-11', 'amc']
# ICUI
# ['NFE', '2019-11-11', 'amc']
# NFE
# ...

# %%
for j in range (15,20):
    base_url="https://api.earningscalendar.net/?date=201911"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191115
# ['JD', '2019-11-15', 'bmo']
# JD
# ['JCP', '2019-11-15', 'bmo']
# JCP
# ['FRO', '2019-11-15', '--']
# FRO
# ['KOD', '2019-11-15', '--']
# KOD
# ['FUV', '2019-11-15', '--']
# FUV
# ['IMAC', '2019-11-15', '--']
# IMAC
# https://api.earningscalendar.net/?date=20191116
# https://api.earningscalendar.net/?date=20191117
# ['CCMP', '2019-11-17', 'amc']
# CCMP
# https://api.earningscalendar.net/?date=20191118
# ['BILI', '2019-11-18', 'amc']
# BILI
# ['CRMT', '2019-11-18', 'amc']
# CRMT
# ['ASH', '2019-11-18', 'amc']
# ASH
# ['SOLO', '2019-11-18', '--']
# SOLO
# ['JACK', '2019-11-18', '--']
# JACK
# ['ZTO', '2019-11-18', 'amc']
# ZTO
# ['WWD', '2019-11-18', 'amc']
# WWD
# ['ASND', '2019-11-18', 'amc']
# ASND
# ['NUAN', '2019-11-18', '--']
# NUAN
# ['KRNT', '2019-11-18', 'amc']
# KRNT
# ['GWGH', '2019-11-18', '--']
# GWGH
# ['SOL', '2019-11-18', '--']
# SOL
# ['RIOT', '2019-11-18', '--']
# RIOT
# ['JAGX', '2019-11-18', '--']
# JAGX
# ...

# %%
for j in range (20,25):
    base_url="https://api.earningscalendar.net/?date=201911"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191120
# ['TGT', '2019-11-20', 'bmo']
# TGT
# ['LOW', '2019-11-20', 'bmo']
# LOW
# ['LB', '2019-11-20', 'amc']
# LB
# ['SQM', '2019-11-20', 'amc']
# SQM
# ['SONO', '2019-11-20', 'amc']
# SONO
# ['PDD', '2019-11-20', 'bmo']
# PDD
# ['ALOT', '2019-11-20', '--']
# ALOT
# ['PFLT', '2019-11-20', 'amc']
# PFLT
# ['LTM', '2019-11-20', '--']
# LTM
# ['SR', '2019-11-20', 'bmo']
# SR
# ['FANH', '2019-11-20', 'amc']
# FANH
# ['LZB', '2019-11-20', 'amc']
# LZB
# ['OCSL', '2019-11-20', 'bmo']
# OCSL
# ['OCSI', '2019-11-20', 'bmo']
# OCSI
# ['IFRX', '2019-11-20', '--']
# IFRX
# https://api.earningscalendar.net/?date=20191121
# ['M', '2019-11-21', 'bmo']
# M
# ['SPLK', '2019-11-21', 'amc']
# SPLK
# ['JWN', '2019-11-21', 'amc']
# JWN
# ['SCVL', '2019-11-21', '--']
# SCVL
# ['ROST', '2019-11-21', 'amc']
# ROST
# ['MANU', '2019-11-21', '--']
# MANU
# ['INTU', '2019-11-21', 'amc']
# INTU
# ['PSTG', '2019-11-21', 'amc']
# PSTG
# ['WSM', '2019-11-21', '--']
# WSM
# ...

# %%
for j in range (25,31):
    base_url="https://api.earningscalendar.net/?date=201911"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-11-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191125
# ['PANW', '2019-11-25', 'amc']
# PANW
# ['A', '2019-11-25', 'amc']
# A
# ['JEC', '2019-11-25', 'bmo']
# JEC
# ['AMBA', '2019-11-25', 'amc']
# AMBA
# ['NAT', '2019-11-25', 'bmo']
# NAT
# ['GSM', '2019-11-25', '--']
# GSM
# ['BECN', '2019-11-25', 'amc']
# BECN
# ['ITRN', '2019-11-25', 'bmo']
# ITRN
# ['MNR', '2019-11-25', 'amc']
# MNR
# ['ENTA', '2019-11-25', '--']
# ENTA
# ['GBDC', '2019-11-25', 'amc']
# GBDC
# ['CAAP', '2019-11-25', '--']
# CAAP
# ['VIOT', '2019-11-25', '--']
# VIOT
# ['OGI', '2019-11-25', 'bmo']
# OGI
# ['FULC', '2019-11-25', '--']
# FULC
# https://api.earningscalendar.net/?date=20191126
# ['VEEV', '2019-11-26', 'amc']
# VEEV
# ['BBY', '2019-11-26', 'bmo']
# BBY
# ['ANF', '2019-11-26', 'bmo']
# ANF
# ['DELL', '2019-11-26', 'amc']
# DELL
# ['DKS', '2019-11-26', 'bmo']
# DKS
# ['NTNX', '2019-11-26', '--']
# NTNX
# ['ADSK', '2019-11-26', 'amc']
# ADSK
# ['BNS', '2019-11-26', 'bmo']
# BNS
# ['ADI', '2019-11-26', 'bmo']
# ...

# %%
for j in range (1,5):
    base_url="https://api.earningscalendar.net/?date=2019120"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191201
# https://api.earningscalendar.net/?date=20191202
# ['RH', '2019-12-02', '--']
# RH
# ['COUP', '2019-12-02', '--']
# COUP
# ['SMAR', '2019-12-02', '--']
# SMAR
# ['DSX', '2019-12-02', 'bmo']
# DSX
# ['LOGC', '2019-12-02', '--']
# LOGC
# ['HX', '2019-12-02', '--']
# HX
# https://api.earningscalendar.net/?date=20191203
# ['CRM', '2019-12-03', 'amc']
# CRM
# ['MRVL', '2019-12-03', '--']
# MRVL
# ['DG', '2019-12-03', '--']
# DG
# ['BMO', '2019-12-03', 'bmo']
# BMO
# ['AZO', '2019-12-03', '--']
# AZO
# ['HPE', '2019-12-03', '--']
# HPE
# ['MDB', '2019-12-03', '--']
# MDB
# ['OLLI', '2019-12-03', '--']
# OLLI
# ['HQY', '2019-12-03', '--']
# HQY
# ['ZS', '2019-12-03', '--']
# ZS
# ['CONN', '2019-12-03', '--']
# CONN
# ['TOL', '2019-12-03', '--']
# TOL
# ['MOV', '2019-12-03', '--']
# MOV
# ['GMS', '2019-12-03', '--']
# GMS
# ['HDS', '2019-12-03', '--']
# HDS
# ['GWRE', '2019-12-03', '--']
# GWRE
# ['DCI', '2019-12-03', 'bmo']
# DCI
# ...

# %%
for j in range (5,10):
    base_url="https://api.earningscalendar.net/?date=2019120"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-0"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191205
# ['LULU', '2019-12-05', '--']
# LULU
# ['AVGO', '2019-12-05', '--']
# AVGO
# ['OKTA', '2019-12-05', 'amc']
# OKTA
# ['AVAV', '2019-12-05', '--']
# AVAV
# ['ULTA', '2019-12-05', 'amc']
# ULTA
# ['WDAY', '2019-12-05', '--']
# WDAY
# ['DLTR', '2019-12-05', '--']
# DLTR
# ['KR', '2019-12-05', '--']
# KR
# ['VMW', '2019-12-05', '--']
# VMW
# ['TITN', '2019-12-05', '--']
# TITN
# ['HPQ', '2019-12-05', '--']
# HPQ
# ['TECD', '2019-12-05', '--']
# TECD
# ['THO', '2019-12-05', '--']
# THO
# ['TD', '2019-12-05', 'bmo']
# TD
# ['GME', '2019-12-05', '--']
# GME
# ['ZUO', '2019-12-05', '--']
# ZUO
# ['PLCE', '2019-12-05', '--']
# PLCE
# ['SIG', '2019-12-05', '--']
# SIG
# ['CMTL', '2019-12-05', '--']
# CMTL
# ['PVH', '2019-12-05', '--']
# PVH
# ['DOCU', '2019-12-05', '--']
# DOCU
# ['GIII', '2019-12-05', '--']
# GIII
# ['EXPR', '2019-12-05', '--']
# EXPR
# ['UNFI', '2019-12-05', '--']
# UNFI
# ['HOME', '2019-12-05', '--']
# HOME
# ...

# %%
for j in range (10,15):
    base_url="https://api.earningscalendar.net/?date=201912"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191210
# ['AEO', '2019-12-10', '--']
# AEO
# ['PLAY', '2019-12-10', '--']
# PLAY
# ['PVTL', '2019-12-10', '--']
# PVTL
# ['ARWR', '2019-12-10', '--']
# ARWR
# ['DBI', '2019-12-10', '--']
# DBI
# ['AXNX', '2019-12-10', '--']
# AXNX
# ['PHX', '2019-12-10', '--']
# PHX
# ['EMMA', '2019-12-10', '--']
# EMMA
# ['SMMT', '2019-12-10', '--']
# SMMT
# ['MMMB', '2019-12-10', '--']
# MMMB
# ['CTXR', '2019-12-10', '--']
# CTXR
# https://api.earningscalendar.net/?date=20191211
# ['TLRD', '2019-12-11', 'amc']
# TLRD
# ['PLAB', '2019-12-11', '--']
# PLAB
# ['NDSN', '2019-12-11', '--']
# NDSN
# ['OXM', '2019-12-11', '--']
# OXM
# ['VRA', '2019-12-11', 'bmo']
# VRA
# ['AVXL', '2019-12-11', '--']
# AVXL
# ['DLHC', '2019-12-11', 'amc']
# DLHC
# https://api.earningscalendar.net/?date=20191212
# ['ADBE', '2019-12-12', '--']
# ADBE
# ['COST', '2019-12-12', '--']
# COST
# ['CIEN', '2019-12-12', '--']
# CIEN
# ['VERU', '2019-12-12', '--']
# VERU
# ...

# %%
for j in range (15,20):
    base_url="https://api.earningscalendar.net/?date=201912"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191215
# https://api.earningscalendar.net/?date=20191216
# ['ORCL', '2019-12-16', '--']
# ORCL
# ['CSBR', '2019-12-16', '--']
# CSBR
# ['HEI', '2019-12-16', '--']
# HEI
# ['LAKE', '2019-12-16', '--']
# LAKE
# ['CVALF', '2019-12-16', '--']
# CVALF
# https://api.earningscalendar.net/?date=20191217
# ['MU', '2019-12-17', '--']
# MU
# ['FDX', '2019-12-17', 'amc']
# FDX
# ['SCS', '2019-12-17', '--']
# SCS
# ['DRI', '2019-12-17', '--']
# DRI
# ['JBL', '2019-12-17', '--']
# JBL
# ['NAV', '2019-12-17', '--']
# NAV
# ['ABM', '2019-12-17', '--']
# ABM
# ['FDS', '2019-12-17', '--']
# FDS
# ['CHWY', '2019-12-17', '--']
# CHWY
# ['WOR', '2019-12-17', '--']
# WOR
# ['AIR', '2019-12-17', '--']
# AIR
# ['LOVE', '2019-12-17', '--']
# LOVE
# ['OTLK', '2019-12-17', '--']
# OTLK
# https://api.earningscalendar.net/?date=20191218
# ['GIS', '2019-12-18', '--']
# GIS
# ['RAD', '2019-12-18', '--']
# RAD
# ['PAYX', '2019-12-18', '--']
# PAYX
# ...

# %%
for j in range (20,25):
    base_url="https://api.earningscalendar.net/?date=201912"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191220
# ['KMX', '2019-12-20', '--']
# KMX
# https://api.earningscalendar.net/?date=20191221
# https://api.earningscalendar.net/?date=20191222
# https://api.earningscalendar.net/?date=20191223
# https://api.earningscalendar.net/?date=20191224
# ['KMX', '2019-12-20', '--']

# %%
for j in range (25,32):
    base_url="https://api.earningscalendar.net/?date=201912"+str(j)
    print (base_url)
    results = requests.get(base_url).json()
    for result in results:
        earnings_date = []
        date = "2019-12-"+str(j)
        earnings_date.append(result.get("ticker"))
        earnings_date.append(date)
        earnings_date.append(result.get("when"))
        earnings.append(earnings_date)
        print(earnings_date)
        print(result.get("ticker"))

earnings[-1]
# Out:
# https://api.earningscalendar.net/?date=20191225
# https://api.earningscalendar.net/?date=20191226
# ['MRUS', '2019-12-26', '--']
# MRUS
# https://api.earningscalendar.net/?date=20191227
# https://api.earningscalendar.net/?date=20191228
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-d49666d752db> in <module>
#       2     base_url="https://api.earningscalendar.net/?date=201912"+str(j)
#       3     print (base_url)
# ----> 4     results = requests.get(base_url).json()
#       5     for result in results:
#       6         earnings_date = []
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...

# %%
df=pd.DataFrame(earnings, columns = ['symbol','date','release_time'])
df.head(30)
# Out:
#    symbol        date release_time
# 0    SFIX  2019-10-01          amc
# 1     MKC  2019-10-01          bmo
# 2    UNFI  2019-10-01          amc
# 3   SSNLF  2019-10-01           --
# 4   DNZOY  2019-10-01           --
# 5   LGRVF  2019-10-01           --
# 6   ASEKY  2019-10-01           --
# 7      NG  2019-10-01          amc
# 8    LNDC  2019-10-01          amc
# 9    CTST  2019-10-01           --
# 10  AMRQQ  2019-10-01           --
# 11    LEN  2019-10-02          bmo
# 12   BBBY  2019-10-02          amc
# 13     LW  2019-10-02          bmo
# 14   PAYX  2019-10-02          bmo
# 15   RECN  2019-10-02           --
# 16    AYI  2019-10-02          bmo
# 17    RPM  2019-10-02          bmo
# 18    STZ  2019-10-03          bmo
# 19   COST  2019-10-03          amc
# 20    SGH  2019-10-03          amc
# 21    PEP  2019-10-03          bmo
# 22  HNNMY  2019-10-03           --
# 23   ANGO  2019-10-03          bmo
# 24   BSET  2019-10-03           --
# 25    DPZ  2019-10-08          bmo
# ...

# %%
df.to_csv(r'df_earnings.csv',index = None, header = True)

# %%
df['symbol'].nunique()
# Out:
# 3629

# %%
len(df)
# Out:
# 5187

# %%
df = df.drop_duplicates()
df.head()
# Out:
#   symbol        date release_time
# 0   SFIX  2019-10-01          amc
# 1    MKC  2019-10-01          bmo
# 2   UNFI  2019-10-01          amc
# 3  SSNLF  2019-10-01           --
# 4  DNZOY  2019-10-01           --

# %%
df.reset_index()
# Out:
#       index symbol        date release_time
# 0         0   SFIX  2019-10-01          amc
# 1         1    MKC  2019-10-01          bmo
# 2         2   UNFI  2019-10-01          amc
# 3         3  SSNLF  2019-10-01           --
# 4         4  DNZOY  2019-10-01           --
# 5         5  LGRVF  2019-10-01           --
# 6         6  ASEKY  2019-10-01           --
# 7         7     NG  2019-10-01          amc
# 8         8   LNDC  2019-10-01          amc
# 9         9   CTST  2019-10-01           --
# 10       10  AMRQQ  2019-10-01           --
# 11       11    LEN  2019-10-02          bmo
# 12       12   BBBY  2019-10-02          amc
# 13       13     LW  2019-10-02          bmo
# 14       14   PAYX  2019-10-02          bmo
# 15       15   RECN  2019-10-02           --
# 16       16    AYI  2019-10-02          bmo
# 17       17    RPM  2019-10-02          bmo
# 18       18    STZ  2019-10-03          bmo
# 19       19   COST  2019-10-03          amc
# ...

# %%
df['symbol'].value_counts()
# Out:
# COST     2
# ASH      2
# ADRO     2
# WGO      2
# BYSI     2
# SEKEY    2
# PRTK     2
# SMMT     2
# ASEKY    2
# DNZOY    2
# MDOMF    2
# RANJY    2
# DSCSY    2
# CYDY     2
# ODT      2
# ONCS     2
# CTST     2
# WBA      2
# UNT      2
# SFIX     2
# UNFI     2
# KNCAY    2
# ATEYY    2
# GWR      2
# NTRP     2
# PAYX     2
# KNX      1
# MPC      1
# ZEN      1
# TOL      1
#         ..
# GPRE     1
# BAS      1
# HAIN     1
# VBLT     1
# GERN     1
# RS       1
# CSFL     1
# MYOK     1
# CPRT     1
# CUTR     1
# VSAT     1
# AVH      1
# SCHW     1
# GPMT     1
# NTNX     1
# DENN     1
# Y        1
# TGEN     1
# AMKR     1
# D        1
# FGEN     1
# PRA      1
# ATEN     1
# IPHI     1
# VLVLY    1
# PTEN     1
# CDW      1
# MOMO     1
# EURN     1
# CATM     1
# Name: symbol, Length: 3629, dtype: int64

# %%
df.loc[]
